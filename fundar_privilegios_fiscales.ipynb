# %%
import numpy as np
import pandas as pd

# %%
cancelaciones  = pd.read_excel('Cancelaciones_2007-2015.xlsx',header=1,)
cancelaciones.set_index(['Año','RFC'], inplace=True)
condonaciones = pd.read_excel('condonacion.xlsx',)
condonaciones.set_index(['Año','RFC'],inplace=True)
cond_y_cancel = pd.read_excel('Condonaciones_y_cancelaciones_2015-2019.xlsx',)
cond_y_cancel.set_index(['rfc', 'nombre'],inplace=True)

# %%
cancelaciones.shape
# Out:
# (23006, 4)

# %%
condonaciones.shape
# Out:
# (148094, 4)

# %%
cond_y_cancel.shape
# Out:
# (99306, 6)

# %%
condonaciones.reset_index().pivot_table(values='Monto (pesos corrientes)',index=['RFC','Contribuyente', 'Tipo de persona'],columns='Año',aggfunc='sum',)
# Out:
# Año                                                                                   2007.0  \
# RFC           Contribuyente                                      Tipo de persona
# AAA390128530  ASOCIACION DE AGENTES ADUANALES DE NUEVO LAREDO AC Persona moral    11691833.0
# AAA870910JNA  ALARCON AGUILAR Y AUDITORES SC                     Persona moral           NaN
# AAA880801SR2  ASESORES Y ACTUARIOS AGENTES DE SEGUROS SA DE CV   Persona moral           NaN
# AAA9603251G0  AGENCIA ADUANAL ALVAREZ CUETO SC                   Persona moral     2573214.0
# AAAA680705LD8 ANTONINO ALMAZAN ARTEAGA                           Persona fisica          NaN
# AAAE3004207Y8 ESTHER ALVAREZ ALMAZAN                             Persona fisica          NaN
# AAAF590308SE0 FILEMON JUAN DE DIOS ALARCON ALCANTARA             Persona fisica     226308.0
# AAAI681126IG1 ISIDORO JOSE ALDANA AGUIRRE                        Persona fisica          NaN
# ...

# %%
cancelaciones.reset_index().pivot_table(values='Monto (pesos corrientes)',index=['RFC','Contribuyente','Tipo persona'],columns='Año',aggfunc='sum',).head()
# Out:
# Año                                                                            2007.0  \
# RFC          Contribuyente                                      Tipo persona
# &MC980915D11 A & M CONSTRUCCIONES Y SERVICIOS INDUSTRIALES S... Persona Moral     NaN
# &SP040220669 A & S PROMOTION WORKING PEOPLE SA DE CV            Persona Moral     NaN
# A&C030729VA8 ANDERSSON & CO. CENTRO DE DISTRIBUCION Y CARDAD... Persona Moral     NaN
# A&S040707F4A ADP & SER SA DE CV                                 Persona Moral     NaN
# AA&051014LV9 ATZ ARCHITECTURE & TECHNOLOGY SA DE CV             Persona Moral     NaN
#
# Año                                                                            2008.0  \
# RFC          Contribuyente                                      Tipo persona
# &MC980915D11 A & M CONSTRUCCIONES Y SERVICIOS INDUSTRIALES S... Persona Moral     NaN
# &SP040220669 A & S PROMOTION WORKING PEOPLE SA DE CV            Persona Moral     NaN
# ...

# %%
cond_y_cancel.reset_index().pivot_table(values='monto',index=['rfc','nombre','persona_tipo'],aggfunc='sum',).sort_values('monto', ascending=False).head(200)
# Out:
#                                                                                       monto
# rfc           nombre                                             persona_tipo
# EIC790601D74  EMPRESAS ICA S.A. B DE C.V.                        M             9.937216e+09
# ICO0612197H1  IMPORTACIONES CONZTANZA SA DE CV                   M             9.528151e+09
# MAR110907UJA  MANUFACTURAS DE ACERO ROLDAN S DE RL               M             5.812952e+09
# EUR000324SA9  EUREKASOLI SA DE CV SOFOM ENR                      M             4.721067e+09
# OME0712062Q9  OMNITRADE MEXICANA SA DE CV                        M             4.350692e+09
# GZE120606PJ9  GRUPO ZERME S DE RL DE CV                          M             3.770740e+09
# CGE891231NH6  CORPORACION GEO S A B DE C V                       M             2.714415e+09
#               COORPORACI”N GEO SAB DE CV                         M             2.714415e+09
# ...

# %%
cond_y_cancel
# Out:
#                                                                  persona_tipo  \
# rfc           nombre
# EIC790601D74  EMPRESAS ICA S.A. B DE C.V.                                   M
#               EMPRESAS ICA S.A. B DE C.V.                                   M
# CGE891231NH6  COORPORACI”N GEO SAB DE CV                                    M
#               CORPORACION GEO S A B DE C V                                  M
# COI001222UG1  CONTROLADORA DE OPERACIONES DE INFRAESTRUCTURA,...            M
#               CONTROLADORA DE OPERACIONES DE INFRAESTRUCTURA,...            M
# GES850101L4A  GOBIERNO DEL ESTADO DE SAN LUIS POTOSI SIN TIPO...            M
# AMH080702RMA  CERVECERÕA MODELO DE M…XICO S. DE R.L. DE C.V.                M
# SSO960923M2A  SERVICIOS DE SALUD DE OAXACA SIN TIPO DE SOCIEDAD             M
# BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BAN...            M
# LCO8906018H7  LABORATORIOS COLUMBIA SA DE CV                                M
# ...

# %%
cond_y_cancel
# Out:
#                                                                  persona_tipo  \
# rfc           nombre
# EIC790601D74  EMPRESAS ICA S.A. B DE C.V.                                   M
#               EMPRESAS ICA S.A. B DE C.V.                                   M
# CGE891231NH6  COORPORACI”N GEO SAB DE CV                                    M
#               CORPORACION GEO S A B DE C V                                  M
# COI001222UG1  CONTROLADORA DE OPERACIONES DE INFRAESTRUCTURA,...            M
#               CONTROLADORA DE OPERACIONES DE INFRAESTRUCTURA,...            M
# GES850101L4A  GOBIERNO DEL ESTADO DE SAN LUIS POTOSI SIN TIPO...            M
# AMH080702RMA  CERVECERÕA MODELO DE M…XICO S. DE R.L. DE C.V.                M
# SSO960923M2A  SERVICIOS DE SALUD DE OAXACA SIN TIPO DE SOCIEDAD             M
# BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BAN...            M
# LCO8906018H7  LABORATORIOS COLUMBIA SA DE CV                                M
# ...
